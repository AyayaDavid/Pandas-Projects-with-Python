# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from encodings.aliases import aliases # Python has a file containing a dictionary of encoding names and associated aliases

# the matplotlib plots will appear directly below the cell in which the plot function was called.
# %matplotlib inline

# %%
# To find encodings that work

# Below line creates a set of all available encodings
#df = df.set_index('Year')
alias_values = set(aliases.values())

for encoding in set(aliases.values()):
    try:
        df=pd.read_csv(r"C:\Users\ayaya\OneDrive\Desktop\Data analyst portfolio\SQL Project\suicide-rates-by-age.csv", nrows=10, encoding=encoding) # read in only 10 lines for faster read     
        print('successful', encoding)
    except:
        pass

df = df.set_index('Countries, Year')
# Out:
# successful gbk
# successful cp1254
# successful cp1256
# successful kz1048
# successful cp775
# successful iso8859_16
# successful mbcs
# successful iso2022_jp
# successful johab
# successful cp1257
# successful iso8859_4
# successful cp861
# successful latin_1
# successful cp857
# successful cp932
# successful cp1255
# successful cp863
# successful cp037
# successful euc_jp
# successful iso8859_14
# successful iso2022_jp_3
# successful iso2022_jp_ext
# successful iso8859_15
# successful iso8859_7
# successful cp1258
# successful tis_620
# successful iso8859_13
# successful iso8859_3
# successful shift_jis_2004
# successful cp1026
# successful mac_cyrillic
# successful cp1125
# successful ptcp154
# successful cp860
# successful mac_latin2
# successful cp1250
# successful ascii
# successful iso2022_jp_2004
# successful iso8859_5
# successful cp1252
# successful shift_jis
# successful shift_jisx0213
# successful cp500
# successful big5
# successful big5hkscs
# successful iso2022_kr
# ...

# %%
# Read in the crime.csv file and use the timestamp as a datetime index
df = pd.read_csv(r"C:\Users\ayaya\OneDrive\Desktop\Data analyst portfolio\SQL Project\suicide-rates-by-age.csv", encoding="ISO-8859-11")

# %%
df.head(10) # Quick check on how the dataset looks like
# Out:
#              Countries Code  Year  Suicide-rates- by- Age 15-24 years of age  \
# 0          Afghanistan  AFG  2019                                       4.71
# 1              Albania  ALB  2019                                       4.67
# 2              Algeria  DZA  2019                                       3.32
# 3               Angola  AGO  2019                                       3.70
# 4  Antigua and Barbuda  ATG  2019                                       0.00
# 5            Argentina  ARG  2019                                      11.77
# 6              Armenia  ARM  2019                                       1.29
# 7            Australia  AUS  2019                                      11.80
# 8              Austria  AUT  2019                                       7.77
# 9           Azerbaijan  AZE  2019                                       4.00
#
#    Suicide-rates- by- Age 25-34 years of age  \
# 0                                       7.60
# ...

# %%
df.shape # Checking the shape of the data. It has 319,073 rows and 17 columns
# Out:
# (183, 11)

# %%
df.duplicated().sum() # Counting the duplicate rows
# Out:
# 0

# %%
df.drop_duplicates(inplace=True) # Dropping the duplicate rows

# %%
df.shape # Checking the shape again to see if dropping the duplicate rows worked
# Out:
# (183, 11)

# %%
df.head(10) # Quick check of the beginning of the dataframe
# Out:
#              Countries Code  Year  Suicide-rates- by- Age 15-24 years of age  \
# 0          Afghanistan  AFG  2019                                       4.71
# 1              Albania  ALB  2019                                       4.67
# 2              Algeria  DZA  2019                                       3.32
# 3               Angola  AGO  2019                                       3.70
# 4  Antigua and Barbuda  ATG  2019                                       0.00
# 5            Argentina  ARG  2019                                      11.77
# 6              Armenia  ARM  2019                                       1.29
# 7            Australia  AUS  2019                                      11.80
# 8              Austria  AUT  2019                                       7.77
# 9           Azerbaijan  AZE  2019                                       4.00
#
#    Suicide-rates- by- Age 25-34 years of age  \
# 0                                       7.60
# ...

# %%
df.tail(10) # Quick check of the end of the dataframe
# Out:
#           Countries Code  Year  Suicide-rates- by- Age 15-24 years of age  \
# 173  United Kingdom  GBR  2019                                       4.94
# 174   United States  USA  2019                                      14.40
# 175         Uruguay  URY  2019                                      20.93
# 176      Uzbekistan  UZB  2019                                      14.09
# 177         Vanuatu  VUT  2019                                      31.40
# 178       Venezuela  VEN  2019                                       2.78
# 179         Vietnam  VNM  2019                                       5.36
# 180           Yemen  YEM  2019                                       7.66
# 181          Zambia  ZMB  2019                                       4.65
# 182        Zimbabwe  ZWE  2019                                      11.46
#
#      Suicide-rates- by- Age 25-34 years of age  \
# 173                                       8.88
# 174                                      23.84
# ...

# %%
pd.options.display.max_rows = 10

# %%
df
# Out:
#                Countries Code  Year  \
# 0            Afghanistan  AFG  2019
# 1                Albania  ALB  2019
# 2                Algeria  DZA  2019
# 3                 Angola  AGO  2019
# 4    Antigua and Barbuda  ATG  2019
# ..                   ...  ...   ...
# 178            Venezuela  VEN  2019
# 179              Vietnam  VNM  2019
# 180                Yemen  YEM  2019
# 181               Zambia  ZMB  2019
# 182             Zimbabwe  ZWE  2019
#
#      Suicide-rates- by- Age 15-24 years of age  \
# 0                                         4.71
# 1                                         4.67
# 2                                         3.32
# 3                                         3.70
# 4                                         0.00
# ..                                         ...
# 178                                       2.78
# 179                                       5.36
# 180                                       7.66
# ...

# %%
df.info() # Summary information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 0 to 182
# Data columns (total 11 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Countries                                  183 non-null    object
#  1   Code                                       183 non-null    object
#  2   Year                                       183 non-null    int64
#  3   Suicide-rates- by- Age 15-24 years of age  183 non-null    float64
#  4   Suicide-rates- by- Age 25-34 years of age  183 non-null    float64
#  5   Suicide-rates- by- Age 35-44 years of age  183 non-null    float64
#  6   Suicide-rates- by- Age 55-64 years         183 non-null    float64
#  7   Suicide-rates- by- Age 75-84 years         183 non-null    float64
#  8   Suicide-rates- by- Age 65-74 years         183 non-null    float64
#  9   Suicide-rates- by- Age 45-54 years         183 non-null    float64
# ...

# %%
df.describe() # summary information on the numeric columns
# Out:
#          Year  Suicide-rates- by- Age 15-24 years of age  \
# count   183.0                                 183.000000
# mean   2019.0                                   7.790109
# std       0.0                                   7.676023
# min    2019.0                                   0.000000
# 25%    2019.0                                   3.445000
# 50%    2019.0                                   5.350000
# 75%    2019.0                                   9.390000
# max    2019.0                                  52.390000
#
#        Suicide-rates- by- Age 25-34 years of age  \
# count                                 183.000000
# mean                                   10.802459
# std                                    11.036354
# min                                     0.000000
# 25%                                     5.085000
# 50%                                     7.600000
# 75%                                    12.390000
# max                                    83.930000
#
# ...

# %%
df.columns
# Out:
# Index(['Countries', 'Code', 'Year',
#        'Suicide-rates- by- Age 15-24 years of age',
#        'Suicide-rates- by- Age 25-34 years of age',
#        'Suicide-rates- by- Age 35-44 years of age',
#        'Suicide-rates- by- Age 55-64 years',
#        'Suicide-rates- by- Age 75-84 years',
#        'Suicide-rates- by- Age 65-74 years',
#        'Suicide-rates- by- Age 45-54 years',
#        'Suicide-rates- by- Age 85+ years of age'],
#       dtype='object')

# %%
# Checking for the number of unique values in each column
for col in df.columns:
    unique_count = df[col].nunique()
    print(col + " has " + str(unique_count) + " unique values")
# Out:
# Countries has 183 unique values
# Code has 183 unique values
# Year has 1 unique values
# Suicide-rates- by- Age 15-24 years of age has 169 unique values
# Suicide-rates- by- Age 25-34 years of age has 171 unique values
# Suicide-rates- by- Age 35-44 years of age has 168 unique values
# Suicide-rates- by- Age 55-64 years has 176 unique values
# Suicide-rates- by- Age 75-84 years has 174 unique values
# Suicide-rates- by- Age 65-74 years has 176 unique values
# Suicide-rates- by- Age 45-54 years has 174 unique values
# Suicide-rates- by- Age 85+ years of age has 179 unique values

# %%
df.nunique()
# Out:
# Countries                                    183
# Code                                         183
# Year                                           1
# Suicide-rates- by- Age 15-24 years of age    169
# Suicide-rates- by- Age 25-34 years of age    171
#                                             ...
# Suicide-rates- by- Age 55-64 years           176
# Suicide-rates- by- Age 75-84 years           174
# Suicide-rates- by- Age 65-74 years           176
# Suicide-rates- by- Age 45-54 years           174
# Suicide-rates- by- Age 85+ years of age      179
# Length: 11, dtype: int64

# %%
df.corr()
# Out:
# C:\Users\ayaya\AppData\Local\Temp\ipykernel_17036\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                            Year  \
# Year                                        NaN
# Suicide-rates- by- Age 15-24 years of age   NaN
# Suicide-rates- by- Age 25-34 years of age   NaN
# Suicide-rates- by- Age 35-44 years of age   NaN
# Suicide-rates- by- Age 55-64 years          NaN
# Suicide-rates- by- Age 75-84 years          NaN
# Suicide-rates- by- Age 65-74 years          NaN
# Suicide-rates- by- Age 45-54 years          NaN
# Suicide-rates- by- Age 85+ years of age     NaN
#
#                                            Suicide-rates- by- Age 15-24 years of age  \
# Year                                                                             NaN
# ...

# %%
df.shape[0]
# Out:
# 183

# %%
sns.heatmap(df.corr(), annot = True)

plt.rcParams['figure.figsize'] = (20,7)

plt.show()
# Out:
# C:\Users\ayaya\AppData\Local\Temp\ipykernel_17036\3230125373.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)

# %%
#Countries with the most Suicide-rates- by- Age 15-24 years of age commmitted on yearly basis? 
df.plot.scatter(x = 'Countries', y = 'Suicide-rates- by- Age 15-24 years of age')
# Out:
# <Axes: xlabel='Countries', ylabel='Suicide-rates- by- Age 15-24 years of age'>

# %%
#Countries with the most Suicide-rates- by- Age 25-34 years of age commmitted on yearly basis? 
df.plot.scatter(x = 'Countries', y = 'Suicide-rates- by- Age 25-34 years of age')
# Out:
# <Axes: xlabel='Countries', ylabel='Suicide-rates- by- Age 25-34 years of age'>

# %%
#Countries with the most Suicide-rates- by- Age 35-44 years of age commmitted on yearly basis? 
df.plot.scatter(x = 'Countries', y = 'Suicide-rates- by- Age 35-44 years of age')
# Out:
# <Axes: xlabel='Countries', ylabel='Suicide-rates- by- Age 35-44 years of age'>
